# %% [markdown]
# # CREATING LEX TRANSCRIPT DATABASE

# %% [markdown]
# In this notebook, we will guide you through the process of creating a Lex Transcript database in MongoDB.

# %% [markdown]
# We will use as input the data from the Youtube videos that are available both in the JSON file `LexFridman_videos.json` but also in the MongoDB collection that we created in `create_video_db.ipynb`. The output will be a new MongoDB collection and a storage folder with a JSON file for each transcript.

# %%
import os
import json
import random
import mongo_utils as mu
from pymongo import UpdateOne
from pymongo.errors import BulkWriteError

# %% [markdown]
# ### MONGODB CONNECTION

# %%
client = mu.connect_to_mongodb()

# %%
db_name = 'lex_podcast'
db = mu.get_database(client, db_name)
db.list_collection_names()
# Out:
# ['LexFridmanPodcast']

# %% [markdown]
# Let's retrieve the videos from the collection using the function `get_documents` defined in the `mongo_utils.py` file.

# %%
colletion_name = 'LexFridmanPodcast'
collection = db[colletion_name]
# Get all the videos in the collection
videos = mu.get_documents(collection, limit=None)
print(f"Number of videos retrieved: {len(videos)}")
print(f"Keys of the videos: {videos[random.choice(list(videos.keys()))].keys()}")
idx = random.choice(list(videos.keys()))
print(f"Example of video:")
print(f"Title of the video: {videos[idx]['title']}")
print(f"Timestamps of the video: {videos[idx]['timestamps']}")
print(f"Description of the video: {videos[idx]['description']}")
# Out:
# Number of videos retrieved: 436
# Keys of the videos: dict_keys(['description', 'duration', 'published_at', 'tags', 'timestamps', 'title', 'video_id'])
# Example of video:
# Title of the video: Travis Stevens: Judo, Olympics, and Mental Toughness | Lex Fridman Podcast #223
# Timestamps of the video: {'0:00': '- Introduction', '4:39': '- What is Judo?', '12:27': "- Travis's signature throw", '17:52': '- Fundamentals', '19:44': '- Throws', '32:36': '- Gripping', '41:09': '- Weight cutting', '1:10:22': '- Injuries', '1:14:22': '- Jiu-Jitsu', '1:18:05': '- Lex on his judo competition experience', '1:21:30': '- Levels of mastery', '1:34:41': '- Matches', '1:48:42': '- Travis inspired Lex to practice judo', '1:54:56': '- London 2012 Olympic games', '2:36:33': '- 2016 Olympic games', '3:10:56': '- Mixed team competition', '3:18:21': '- The value of epic throws', '3:21:49': '- Shohei Ono', '3:28:11': '- Chess', '3:33:14': '- The coach', '3:39:50': '- Advice for young people'}
# Description of the video: Travis Stevens is the 2016 Olympic Judo silver medalist and BJJ black belt. Please support this podcast by checking out our sponsors:
# - Justworks: https://justworks.com
# - Indeed: https://indeed.com/lex to get $75 credit
# - MasterClass: https://masterclass.com/lex to get 15% off
# - Eight Sleep: https://www.eightsleep.com/lex and use code LEX to get special savings
#
# EPISODE LINKS:
# Travis's Website: https://www.travisstevensgrappling.com/
# Travis's Twitter: https://twitter.com/judosilencer
# Travis's Youtube Channel: https://www.youtube.com/c/TravisStevensgrappling
# Travis's Instagram: https://www.instagram.com/judosilencer
#
# PODCAST INFO:
# Podcast website: https://lexfridman.com/podcast
# Apple Podcasts: https://apple.co/2lwqZIr
# Spotify: https://spoti.fi/2nEwCF8
# RSS: https://lexfridman.com/feed/podcast/
# Full episodes playlist: https://www.youtube.com/playlist?list=PLrAXtmErZgOdP_8GztsuKi9nrraNbKKp4
# Clips playlist: https://www.youtube.com/playlist?list=PLrAXtmErZgOeciFP3CBCIEElOJeitOr41
#
# OUTLINE:
# 0:00 - Introduction
# 4:39 - What is Judo?
# 12:27 - Travis's signature throw
# 17:52 - Fundamentals
# 19:44 - Throws
# 32:36 - Gripping
# 41:09 - Weight cutting
# 1:10:22 - Injuries
# 1:14:22 - Jiu-Jitsu
# 1:18:05 - Lex on his judo competition experience
# 1:21:30 - Levels of mastery
# 1:34:41 - Matches
# 1:48:42 - Travis inspired Lex to practice judo
# 1:54:56 - London 2012 Olympic games
# 2:36:33 - 2016 Olympic games
# 3:10:56 - Mixed team competition
# 3:18:21 - The value of epic throws
# 3:21:49 - Shohei Ono
# 3:28:11 - Chess
# 3:33:14 - The coach
# 3:39:50 - Advice for young people
#
# SOCIAL:
# - Twitter: https://twitter.com/lexfridman
# - LinkedIn: https://www.linkedin.com/in/lexfridman
# - Facebook: https://www.facebook.com/lexfridman
# - Instagram: https://www.instagram.com/lexfridman
# - Medium: https://medium.com/@lexfridman
# - Reddit: https://reddit.com/r/lexfridman
# - Support on Patreon: https://www.patreon.com/lexfridman

# %% [markdown]
# ### DEFINE YOUTUBE FUNCTIONS

# %% [markdown]
# In order to get the transcripts from the Youtube videos, we will use the `youtube-transcript-api` library.

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.formatters import JSONFormatter, TextFormatter, PrettyPrintFormatter

# %%
def get_transcript(video_id: str, style: str = None) -> tuple[list, bool]:
    """
    Get the transcript for a YouTube video.
    :param video_id: The ID of the YouTube video.
    :param style: The style of the transcript. Can be 'json', 'text', 'pretty' or None.
    :return: The transcript and a boolean indicating if the transcript was retrieved successfully.
    """
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id)

        # Potentially format the transcript
        formatter1 = JSONFormatter()
        formatter2 = TextFormatter()
        formatter3 = PrettyPrintFormatter()
        if not style:
            return transcript, True
        elif style.lower()=='json':
            return formatter1.format_transcript(transcript), True
        elif style.lower()=='text':
            return formatter2.format_transcript(transcript), True
        elif style.lower()=='pretty':
            return formatter3.format_transcript(transcript), True
    except Exception as e:
        print(f"Error retrieving transcript for {video_id}: {str(e)}")
        return None, False

# %% [markdown]
# Let's retrieve the transcript for a random video. Pay attention to the format of the transcript.

# %%
# choosing a random video
idx = random.choice(list(videos.keys()))
video_id = idx
video_data = videos[video_id]

# %%
print(f"Title of the video:\n{video_data['title']}")
transcript, success = get_transcript(video_id=video_id, style=None)
print(f"Transcript retrieved successfully: {success}")
if success:
    print(f"Length of the transcript: {len(transcript)}")
    print(f"Transcript: {transcript}")
# Out:
# Title of the video:
# Glenn Loury: Race, Racism, Identity Politics, and Cancel Culture | Lex Fridman Podcast #285
# Transcript retrieved successfully: True
# Length of the transcript: 5918
# Transcript: [{'text': 'i hate', 'start': 0.08, 'duration': 3.119}, {'text': "affirmative action i don't just disagree", 'start': 1.439, 'duration': 3.36}, {'text': "with it i don't just think it's", 'start': 3.199, 'duration': 4.64}, {'text': 'against the 14th amendment i hate it', 'start': 4.799, 'duration': 5.041}, {'text': 'the hatred comes from an understanding', 'start': 7.839, 'duration': 3.92}, {'text': 'that it is a band-aid that it is a', 'start': 9.84, 'duration': 3.839}, {'text': 'substitute for the actual development', 'start': 11.759, 'duration': 3.76}, {'text': 'over the capacities of our people to', 'start': 13.679, 'duration': 3.68}, {'text': 'compete they want to tell african', 'start': 15.519, 'duration': 4.321}, {'text': 'americans uh pat us on the head', 'start': 17.359, 'duration': 4.08}, {'text': "uh we're gonna have a separate program", 'start': 19.84, 'duration': 3.599}, {'text': "for you we're gonna give you a side door", 'start': 21.439, 'duration': 4.0}, {'text': "that you can come into that doesn't make", 'start': 23.439, 'duration': 3.92}, {'text': 'us any smarter', 'start': 25.439, 'duration': 4.801}, {'text': "it doesn't make us any more creative", 'start': 27.359, 'duration': 6.72}, {'text': "and it doesn't make us any more fit", 'start': 30.24, 'duration': 5.76}, {'text': "for the actual competition that's", 'start': 34.079, 'duration': 4.961}, {'text': 'unfolding before us', 'start': 36.0, 'duration': 3.04}, {'text': 'the following is a conversation with', 'start': 39.44, 'duration': 3.76}, {'text': 'glenn lowery professor of economics and', 'start': 40.96, 'duration': 4.88}, {'text': 'social sciences at brown university he', 'start': 43.2, 'duration': 4.64}, {'text': 'is one of the great minds and', 'start': 45.84, 'duration': 4.16}, {'text': 'communicators of our time writing and', 'start': 47.84, 'duration': 5.52}, {'text': 'speaking about race and inequality', 'start': 50.0, 'duration': 5.92}, {'text': 'i highly encourage you to listen to his', 'start': 53.36, 'duration': 5.679}, {'text': 'show on youtube and stack simply called', 'start': 55.92, 'duration': 4.959}, {'text': 'the glen show', 'start': 59.039, 'duration': 3.84}, {'text': 'this is the lex friedman podcast to', 'start': 60.879, 'duration': 3.92}, {'text': 'support it please check out our sponsors', 'start': 62.879, 'duration': 4.56}, {'text': 'in the description and now dear friends', 'start': 64.799, 'duration': 3.921}, {'text': "here's glenn", 'start': 67.439, 'duration': 2.72}, {'text': 'lowry', 'start': 68.72, 'duration': 3.04}, {'text': 'martin luther king juniors i have a', 'start': 70.159, 'duration': 3.681}, {'text': 'dream speech i think is the greatest', 'start': 71.76, 'duration': 4.24}, {'text': "speech in american history if i may i'd", 'start': 73.84, 'duration': 4.88}, {'text': 'like to read a few words of it sure and', 'start': 76.0, 'duration': 6.32}, {'text': 'uh ask you a question about this dream', 'start': 78.72, 'duration': 5.039}, {'text': 'i have a dream', 'start': 82.32, 'duration': 3.839}, {'text': 'that one day this nation will rise up', 'start': 83.759, 'duration': 3.921}, {'text': 'and live out the true meaning of its', 'start': 86.159, 'duration': 2.721}, {'text': 'creed', 'start': 87.68, 'duration': 3.759}, {'text': 'we hold these truths to be self-evident', 'start': 88.88, 'duration': 5.599}, {'text': 'that all men are created equal', 'start': 91.439, 'duration': 4.72}, {'text': 'i have a dream', 'start': 94.479, 'duration': 4.32}, {'text': 'that one day on the red hills of georgia', 'start': 96.159, 'duration': 4.96}, {'text': 'the sons of former slaves and the sons', 'start': 98.799, 'duration': 4.721}, {'text': 'of former slave owners will be able to', 'start': 101.119, 'duration': 4.0}, {'text': 'sit down together at the table of', 'start': 103.52, 'duration': 3.36}, {'text': 'brotherhood', 'start': 105.119, 'duration': 4.0}, {'text': 'i have a dream that one day even the', 'start': 106.88,  ...

# %% [markdown]
# ### STRUCTURING THE DATA

# %% [markdown]
# We retrieve some important information now regarding the videos and the transcripts. We need now to organise them in a new structured way in order to create a Lex Transcript database.
# 1. We have the video ID, the title, the date and time of the video, the full text and the transcript.
# 2. The transcript is a list of dictionaries with the following structure:
#     - `start`: The start time of the transcript in seconds.
#     - `duration`: The duration of the transcript in seconds.
#     - `text`: The text of the transcript.
# 3. We also have as optional information the timestamps. Timestamps are dictionaries with the following structure:
#     - `start`: The start time of the timestamp in HH:MM:SS format.
#     - `timestamp`: The description of the timestamp.

# %% [markdown]
# Let's write a function that organises the data into a new structured way.

# %%
def parse_timestamp(timestamp: str) -> int:
    """
    Parse a timestamp in the format HH:MM:SS or MM:SS to seconds.
    :param timestamp: The timestamp to parse.
    :return: The timestamp in seconds.
    """
    parts = timestamp.split(':')
    if len(parts) == 2:
        return int(parts[0]) * 60 + int(parts[1])
    elif len(parts) == 3:
        return int(parts[0]) * 3600 + int(parts[1]) * 60 + int(parts[2])
    else:
        raise ValueError(f"Invalid timestamp format: {timestamp}")
    

def create_transcript_structure(video_data: dict, transcript: list) -> dict:
    """
    Create a structured transcript for a video. The bulk of this function deals with dividing 
    the transcript into sections based on the timestamps.
    :param video_data: The video data.
    :param transcript: The transcript of the video.
    :return: The structured transcript.
    """
    # Initialize the structure with the video data
    structure = {
        "video_id": video_data['video_id'],
        "title": video_data['title'],
        "date": video_data['published_at'].split('T')[0],
        "transcript": [],
        "full_text": ""
    }
    timestamps = video_data.get('timestamps', {})
    # If there are timestamps, we will use them to create the transcript structure
    if timestamps:
        # Parse the timestamps and sort them by the start time
        timestamp_seconds = [(parse_timestamp(t), t, desc.lstrip('- ').strip()) for t, desc in timestamps.items()]
        timestamp_seconds.sort(key=lambda x: x[0])
        # Initialize the current section index and text
        current_section_index = 0
        current_section_text = []
        # Iterate over the transcript
        for line in transcript:
            start_time = float(line['start'])
            # If the start time is greater than the next timestamp, we save the current section
            while (current_section_index + 1 < len(timestamp_seconds) and 
                   start_time >= timestamp_seconds[current_section_index + 1][0]):
                # Save the current section
                if current_section_text:
                    structure['transcript'].append({
                        "timestamp": timestamp_seconds[current_section_index][1],
                        "section": timestamp_seconds[current_section_index][2],
                        "text": ' '.join(current_section_text)
                    })
                # Move to the next section
                current_section_index += 1
                # Reset the current section text    
                current_section_text = []
            # Add the text to the current section
            current_section_text.append(line['text'])

        # Add the last section
        if current_section_text:
            structure['transcript'].append({
                "timestamp": timestamp_seconds[current_section_index][1],
                "section": timestamp_seconds[current_section_index][2],
                "text": ' '.join(current_section_text)
            })
    else:
        # If no timestamps, create a single section with the full transcript
        structure['transcript'].append({
            "timestamp": "0:00",
            "section": "Full Transcript",
            "text": ' '.join(line['text'] for line in transcript)
        })

    structure['full_text'] = ' '.join(line['text'] for line in transcript)

    return structure

# %% [markdown]
# Here is an example of the transcript structure for the random video chosen before.

# %%
transcript_structure = create_transcript_structure(video_data=video_data, transcript=transcript)
print(f"Transcript structure keys: {transcript_structure.keys()}")
for key in transcript_structure.keys():
    if key == 'transcript':
        for section in transcript_structure[key]:
            print(f"{section['timestamp']} - {section['section']}:\n{section['text'][:150]}...\n")
    print(f"{key}:\n{transcript_structure[key]}")
# Out:
# Transcript structure keys: dict_keys(['video_id', 'title', 'date', 'transcript', 'full_text'])
# video_id:
# YbJZnShMQAo
# title:
# Glenn Loury: Race, Racism, Identity Politics, and Cancel Culture | Lex Fridman Podcast #285
# date:
# 2022-05-14
# 0:00 - Introduction:
# i hate affirmative action i don't just disagree with it i don't just think it's against the 14th amendment i hate it the hatred comes from an understa...
#
# 1:10 - Martin Luther King Jr.:
# martin luther king juniors i have a dream speech i think is the greatest speech in american history if i may i'd like to read a few words of it sure a...
#
# 9:58 - History of slavery:
# what do you learn about human nature by looking at the history of slavery in america oh my so what does that tell you about people well i think of two...
#
# 24:36 - Equality of outcome:
# on this topic of equality in uh the 21st century so what does equality mean today if you start to think about this idea of equality of outcome or the ...
#
# 40:59 - Math and economics:
# mathematics and human nature and so which is why you ended up going into economics at one of the great economics programs in the world at mit and gett...
#
# 57:15 - Racial groups:
# well is there some general things that are really powerful in terms of you said nation religion those are groups yeah can you group people nicely in h...
#
# 1:10:31 - Black patriotism:
# we form tribes as humans throughout human history formed tribes and have directed hate toward other tribes and sometimes violence and destruction and ...
#
# 1:20:24 - MLK and Malcolm X:
# let me return to the question of dr king and another powerful impactful individual malcolm x to ask you the question well first people often perhaps i...
#
# 1:34:04 - Joe Rogan controversy:
# in part you're troubled by the term african-american so words are funny things until they're not so let me ask you about what i think is one of the mo...
#
# 1:53:21 - Accusation of racism:
# if i can get your comment maybe you have ideas because it does seem that this kind of attack um works of being called a racist being called um maybe n...
#
# 2:01:05 - Elon Musk and Twitter:
# speaking of children uh charismatic children uh there's a guy named elon musk who might be a candidate for such an unraveling right you mentioned uh t...
#
# 2:06:39 - Universities:
# you've talked about you are at a prestigious university brown university brown university uh and you've mentioned that universities might be in troubl...
#
# 2:15:16 - Cognitive inequality:
# you had this conversation you put on yourself stack with jordan uh jordan peterson about cognitive inequality i think it's titled wrestling with cogni...
#
# 2:27:42 - Politics:
# let me ask you about your politics uh so you've recently said that you're a conservative leaning i mean maybe that's a day-to-day thing um maybe you c...
#
# 2:47:08 - Ketanji Brown Jackson:
# i know you said you're angry um or dislike affirmative action let me ask you about something that even to my ear cut wrong um now i'm relatively apoli...
#
# 2:53:11 - Thomas Sowell:
# um let me ask you about thomas solo you mentioned him he's a colleague and somebody who's an influence what uh in the space of ideas so what broadly w...
#
# 2:58:26 - Barack Obama:
# this in the very beginning that we were talking about how did it feel uh that seems like forever ago that in 2008 barack obama became president now at...
#
# 3:17:03 - Mortality:
# glenn you've lived an incredible life a productive one but just representing um some powerful ideas some powerful ideals but life comes to an end yeah...
#
# 3:29:17 - Meaning of life:
# what's the meaning of life glenn larry that's the meaning of life yeah let's go let's go what's the why or is that something economists and social sci...
#
# transcript:
# [{'timestamp': '0:00', 'section': 'Introduction', 'text': "i hate affirmative action i don't just disagree with it i don't just think it's against the 14th amendment i hate it the hatred comes from an understanding that it is a band-aid that it is a substitute for the actual development over the capacities of our people to compete they want to tell african americans uh pat us on the head uh we're gonna have a separate program for you we're gonna give you a side door that you can come into that doesn't make us any smarter it doesn't make us any more creative and it doesn't make us any more fit for the actual competition that's unfolding before us the following is a conversation with glenn lowery professor of economics and social sciences at brown university he is one of the great minds and communicators of our time writing and speaking about race and inequality i highly encourage you to listen to his show on youtube and stack simply called the glen show this is the lex friedman podcast to support it please check out our sponsors in the description and now dear friends here's glenn lowry"}, {'timestamp': '1:10', 'section': 'Martin Luther King Jr.', 'text': "martin luther king juniors i have a dream speech i think is the greatest speech in american history if i may i'd like to read a few words of it sure and uh ask you a question about this dream i have a dream that one day this nation will rise up and live out the true meaning of its creed we hold these truths to be self-evident that all men are created equal i have a dream that one day on the red hills of georgia the sons of former slaves and the sons of former slave owners will be able to sit down together at the table of brotherhood i have a dream that one day even the state of mississippi a state sweltering with the heat of injustice sweltering with the heat of oppression will be transformed into an oasis of freedom and justice i have a dream that my four little children will one day live in a nation where they will not be judged by the color of their skin but by the content of their character i have a dream today first of all damn i mentioned to you offline i immigrated to to america and this is why i love this country this is one of the great species that represents what this country is about yeah so what is this ideal of equality uh that we should strive for as a nation this that all men are created equal what does that mean to you this equality well if we put this in historical context king is speaking in 1963 when he gives that speech it's exactly 100 years after abraham lincoln signs the emancipation proclamation declaring the enslaved people to be free they're not yet citizens in 1863 but the end of slavery is has become the position of the federal government when lincoln issues that emancipation proclamation so putting it in context enslaved people four million or so african descended enslaved people how do they become citizens how do they become in this uh status of subjugation and domination and stigma and exclusion how do they become citizens it seems to me that that's the that's this the heart of it the the equality that king is talking about is an equality of status as members of the nation as free and equal citizens within the republic now i think it's really important to understand that slavery was not merely a legal order but it was also a social system that had the symbolism attached to it they had a big journey to make from their subjugated status as serfs as landless people as uneducated unfit for citizenship really in the minds of many so i think that's what in 1963 100 years later that king is appealing to this idea that when thomas jefferson in the declaration of independence writes these words all men are created equal and endowed by their creator with certain inalienable rights he didn't thomas jefferson a slave owner didn't have in mind when he wrote those words the people who were slaves but by the time you get to 1963 king is invoking this idea all ...
# full_text:
# i hate affirmative action i don't just disagree with it i don't just think it's against the 14th amendment i hate it the hatred comes from an understanding that it is a band-aid that it is a substitute for the actual development over the capacities of our people to compete they want to tell african americans uh pat us on the head uh we're gonna have a separate program for you we're gonna give you a side door that you can come into that doesn't make us any smarter it doesn't make us any more creative and it doesn't make us any more fit for the actual competition that's unfolding before us the following is a conversation with glenn lowery professor of economics and social sciences at brown university he is one of the great minds and communicators of our time writing and speaking about race and inequality i highly encourage you to listen to his show on youtube and stack simply called the glen show this is the lex friedman podcast to support it please check out our sponsors in the description and now dear friends here's glenn lowry martin luther king juniors i have a dream speech i think is the greatest speech in american history if i may i'd like to read a few words of it sure and uh ask you a question about this dream i have a dream that one day this nation will rise up and live out the true meaning of its creed we hold these truths to be self-evident that all men are created equal i have a dream that one day on the red hills of georgia the sons of former slaves and the sons of former slave owners will be able to sit down together at the table of brotherhood i have a dream that one day even the state of mississippi a state sweltering with the heat of injustice sweltering with the heat of oppression will be transformed into an oasis of freedom and justice i have a dream that my four little children will one day live in a nation where they will not be judged by the color of their skin but by the content of their character i have a dream today first of all damn i mentioned to you offline i immigrated to to america and this is why i love this country this is one of the great species that represents what this country is about yeah so what is this ideal of equality uh that we should strive for as a nation this that all men are created equal what does that mean to you this equality well if we put this in historical context king is speaking in 1963 when he gives that speech it's exactly 100 years after abraham lincoln signs the emancipation proclamation declaring the enslaved people to be free they're not yet citizens in 1863 but the end of slavery is has become the position of the federal government when lincoln issues that emancipation proclamation so putting it in context enslaved people four million or so african descended enslaved people how do they become citizens how do they become in this uh status of subjugation and domination and stigma and exclusion how do they become citizens it seems to me that that's the that's this the heart of it the the equality that king is talking about is an equality of status as members of the nation as free and equal citizens within the republic now i think it's really important to understand that slavery was not merely a legal order but it was also a social system that had the symbolism attached to it they had a big journey to make from their subjugated status as serfs as landless people as uneducated unfit for citizenship really in the minds of many so i think that's what in 1963 100 years later that king is appealing to this idea that when thomas jefferson in the declaration of independence writes these words all men are created equal and endowed by their creator with certain inalienable rights he didn't thomas jefferson a slave owner didn't have in mind when he wrote those words the people who were slaves but by the time you get to 1963 king is invoking this idea all men and of course he means all persons he doesn't only mean men he means men and women are created equal he wants this idea to be ...

# %% [markdown]
# ### CREATING AND POPULATING THE NEW COLLECTION

# %% [markdown]
# The only step we are missing is to create a new collection in the already existing database and populate it with the structured data for all the videos.

# %% [markdown]
# As for the videos collection, we will create a new collection by inserting one initial document and using the `createDB_from_data`function in the `mongo_utils.py` file.

# %%
video_list = list(videos.keys())
print(len(video_list))
first_video = video_list.pop()
print(first_video)
print(len(video_list))
videos[first_video]
# Out:
# 436
# piHkfmeU7Wo
# 435
# {'description': '',
#  'duration': 'PT57M54S',
#  'published_at': '2018-05-29T13:16:25Z',
#  'tags': None,
#  'timestamps': None,
#  'title': 'Christof Koch: Consciousness | Lex Fridman Podcast #2',
#  'video_id': 'piHkfmeU7Wo'}

# %%
db_name = 'lex_podcast'     # the same database we used before
collection_name = 'Podcast_transcripts'     # new collection name (new collection)
# retrieve the transcript for the first video
transcript, success = get_transcript(video_id=first_video, style=None)
if success:
    # create the structured document
    initial_document = create_transcript_structure(video_data=videos[first_video], transcript=transcript)
    print(f"Initial document created with keys: {initial_document.keys()}")
    # create the database
    db = mu.createDB_from_data(
        client=client, 
        database_name=db_name, 
        collection_name=collection_name, 
        initial_document=initial_document, 
        custom_id=first_video
    )
    if db is None:
        # this means that the database or the collection already exists
        db = mu.get_database(client, db_name)
else:
    print(f"Error retrieving transcript for {first_video}: {transcript}")
# Out:
# Initial document created with keys: dict_keys(['video_id', 'title', 'date', 'transcript', 'full_text'])
# Database 'lex_podcast' already exists.
# Database 'lex_podcast' and collection 'Podcast_transcripts' created successfully.
# Inserted document with ID: piHkfmeU7Wo
# Database 'lex_podcast' created with collection 'Podcast_transcripts'.

# %%
# Check if the database and the collection were created
print(f"Databases in the client: {client.list_database_names()}")
print(f"Collections in the database '{db_name}': {db.list_collection_names()}")

collection = db[collection_name]
all_documents = list(collection.find())
print(f"Number of documents in the collection: {len(all_documents)}")
if len(all_documents) <= 10:
    print("All documents in the collection:")
    for doc in all_documents:
        print(doc)
# Out:
# Databases in the client: ['admin', 'config', 'lex_podcast', 'local']
# Collections in the database 'lex_podcast': ['Podcast_transcripts', 'LexFridmanPodcast']
# Number of documents in the collection: 1
# All documents in the collection:
# {'_id': 'piHkfmeU7Wo', 'video_id': 'piHkfmeU7Wo', 'title': 'Christof Koch: Consciousness | Lex Fridman Podcast #2', 'date': '2018-05-29', 'transcript': [{'timestamp': '0:00', 'section': 'Full Transcript', 'text': "as part of MIT course success zero nine nine on artificial general intelligence I got a chance to sit down with Christophe Coe who's one of the seminal figures in neurobiology in neuroscience and generally in the study of consciousness he is the president the chief scientific officer of the Allen Institute for brain science in Seattle from 1986 to 2013 he was the professor at Caltech before that he was at MIT he is extremely well sited over a hundred thousand citations his research his writing his ideas have had big impact on the scientific community and the general public in the way we think about consciousness in the way we see ourselves as human beings he's the author of several books the quest for consciousness and your biological approach and a more recent book consciousness confessions of a romantic reductionist if you enjoy this conversation this course subscribe click the little bell I got to make sure you never miss a video and in the comments leave suggestions for any people you'd like to see be part of the course or any ideas that you would like us to explore thanks very much I hope you enjoy okay before we delve into the beautiful mysteries of consciousness let's zoom out a little bit and let me ask do you think there's intelligent life out there in the universe yes I do believe so we have no evidence of it but I think the probabilities are overwhelming in favor of it give me a universe where we have 10 to the 11 galaxies and each galaxy is between 10 to the 11 10 to the 12 stars and we know more stars have one or more planets so how does that make you feel it still makes me feel special because I have experiences I feel the world I experience the world and independent of whether there are other creatures out there I still feel the world and I have access to this world in this very strange compelling way and that's the core of human existence now he said human do you think if those intelligent creatures are out there do you think they experience their world yes they evolved if they are product of natural evolution if it would have to be they will also experience their own world so consciousness isn't just a human your ID it's it's much wider it's probably it may be spread across all of biology we have the only thing that we have special is we can talk about it of course not all people can talk about the babies and little children can talk about the patients who have have a Stoke and let's see the left inferior frontal gyrus can talk about it but most normal adult people can talk about it and so we think that makes us special compared to little monkeys a dogs or cats or mice or all the other creatures that we share the planet with but all the evidence seems to suggest that they to experience the world and so it's overwhelmingly likely that other alien that aliens would also experience their world of course differently because they have a difference in serum they've different sense of they had a very different environment but the fact that I would strongly suppose that they also have experiences if your pain and pleasure and see in some sort of spectrum and here and have all the other sensors of course their language if they have one would be different so we might not be able to understand their poetry about the experiences that they have that's correct right so in a talk in a video I've heard you mention support so a DAC sound that you came up with there you go up with as part of your family when you were young first of all you're a technically a Midwestern boy you just secondly yes after that you traveled around a bit and it's a little bit of the accent you talked about support so the DAC solid having these elements of humaneness of consciousness that he discovered so I just wanted to ask can you look bac ...

# %% [markdown]
# Now we need to populate the whole collection with the rest of the videos. We won't use a for loop because the documents are pretty large. Instead, we are going to create a new function that will process and store the videos in batches.

# %%
def process_and_store_videos(collection, videos, local_storage: bool = False, verbose: bool = False):
    """
    Process and store videos in batches.
    :param collection: The MongoDB collection to store the videos.
    :param videos: The videos to process and store.
    :param local_storage: Whether to store the videos locally as JSON files.
    :param verbose: Whether to print verbose output.
    """
    if local_storage:
        json_storage_dir = 'JSON_storage'
        os.makedirs(json_storage_dir, exist_ok=True)

    bulk_operations = []
    missing_transcripts = []
    processed_count = 0
    for video_id, video_data in videos.items():
        if verbose:
            print(f"Processing video: {video_id}: {video_data['title']}")
        # retrieve the transcript for the video
        transcript, success = get_transcript(video_id=video_id)
        # check if the transcript was retrieved successfully and if it has more than 5 lines
        if success and len(transcript) > 5:
            # create the structured document
            structure = create_transcript_structure(video_data=video_data, transcript=transcript)

            if local_storage:
                # Save JSON file only if it is specified
                filename = f"{video_id}.json"
                with open(os.path.join(json_storage_dir, filename), 'w', encoding='utf-8') as f:
                    json.dump(structure, f, ensure_ascii=False, indent=2)
            
            # Prepare upsert operation
            bulk_operations.append(
                UpdateOne(
                    {"_id": video_id},
                    {"$set": structure},
                    upsert=True
                )
            )
            processed_count += 1
            print(f'Processed transcript number {processed_count}')
            if verbose:
                print(f"Processed transcript for {video_data['title']}")
        else:
            # if the transcript is not retrieved successfully, we add the video ID to the missing transcripts list and won't insert it in the database
            print(f"Transcript for {video_data['title']} not retrieved successfully")
            missing_transcripts.append(video_id)

        # Perform bulk upsert every 50 operations or at the end
        if len(bulk_operations) >= 50 or video_id == list(videos.keys())[-1]:
            if verbose:
                print(f"Performing bulk upsert for {len(bulk_operations)} videos")
            try:
                result = collection.bulk_write(bulk_operations)
                print(f"Bulk upsert result: {result.bulk_api_result}")
            except BulkWriteError as bwe:
                print(f"Bulk write error: {bwe.details}")
            bulk_operations = []

    return missing_transcripts

# %% [markdown]
# NB: note that this function is able to save the transcript also in a local folder called `JSON_storage`. If this folder does not exist, it will be created. The transcripts will be saved in JSON format. The reason for saving the transcripts is reproducibility (also for people not using MongoDB).

# %%
# Delete the video we inserted before from videos dictionary
del videos[first_video]
# Process and store the rest of the videos
missing_transcripts = process_and_store_videos(
    collection=collection, 
    videos=videos, 
    local_storage=True, 
    verbose=False,
)
# Out:
# Processed transcript number 1
# Processed transcript number 2
# Processed transcript number 3
# Processed transcript number 4
# Processed transcript number 5
# Processed transcript number 6
# Processed transcript number 7
# Processed transcript number 8
# Processed transcript number 9
# Processed transcript number 10
# Processed transcript number 11
# Processed transcript number 12
# Processed transcript number 13
# Processed transcript number 14
# Processed transcript number 15
# Processed transcript number 16
# Processed transcript number 17
# Processed transcript number 18
# Processed transcript number 19
# Processed transcript number 20
# Processed transcript number 21
# Processed transcript number 22
# Processed transcript number 23
# Processed transcript number 24
# Processed transcript number 25
# Processed transcript number 26
# Processed transcript number 27
# Processed transcript number 28
# Processed transcript number 29
# Processed transcript number 30
# Processed transcript number 31
# Processed transcript number 32
# Processed transcript number 33
# Processed transcript number 34
# Processed transcript number 35
# Processed transcript number 36
# Processed transcript number 37
# Processed transcript number 38
# Processed transcript number 39
# Processed transcript number 40
# Processed transcript number 41
# Processed transcript number 42
# Processed transcript number 43
# Processed transcript number 44
# Processed transcript number 45
# Processed transcript number 46
# Processed transcript number 47
# Processed transcript number 48
# Processed transcript number 49
# Processed transcript number 50
# Bulk upsert result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 50, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': [{'index': 0, '_id': 'Gi8LUnhP5yU'}, {'index': 1, '_id': 'J7aiEwp1x9k'}, {'index': 2, '_id': 'Kbk9BiPhm7o'}, {'index': 3, '_id': 'WA9gVKKPsBo'}, {'index': 4, '_id': '2oxdDKHdcM8'}, {'index': 5, '_id': 'ZIyB9e_7a4c'}, {'index': 6, '_id': 'e-gwvmhyU7A'}, {'index': 7, '_id': 'wwhTfyX9J34'}, {'index': 8, '_id': 'XJTMQtE-MIo'}, {'index': 9, '_id': 'NNr6gPelJ3E'}, {'index': 10, '_id': '4iuepdI3wCU'}, {'index': 11, '_id': 'pwN8u6HFH8U'}, {'index': 12, '_id': 'tdv7r2JSokI'}, {'index': 13, '_id': 'TXabC2Ave74'}, {'index': 14, '_id': 'F3Jd9GI6XqE'}, {'index': 15, '_id': 'yEou104m_P0'}, {'index': 16, '_id': 'sG8u6owzad4'}, {'index': 17, '_id': '_El9riy9Zjw'}, {'index': 18, '_id': '0cn3VBjfN8g'}, {'index': 19, '_id': 'k7aQEqDbuf8'}, {'index': 20, '_id': 'GXgGR8KxFao'}, {'index': 21, '_id': 'jvqFAi7vkBc'}, {'index': 22, '_id': '1X_KdkoGxSs'}, {'index': 23, '_id': 'iAlwZyRUOVM'}, {'index': 24, '_id': '5t1vTLU7s40'}, {'index': 25, '_id': 'qa-wl8_wpZA'}, {'index': 26, '_id': 'f_lRdkH_QoY'}, {'index': 27, '_id': 'PgGKhsWhUu8'}, {'index': 28, '_id': '5VnbBCm_ZyQ'}, {'index': 29, '_id': 'oFSyNdQf5uk'}, {'index': 30, '_id': 'tYrdMjVXyNg'}, {'index': 31, '_id': 'zMYvGf7BA9o'}, {'index': 32, '_id': '9qfwPv7clEw'}, {'index': 33, '_id': '8fEEbKJoNbU'}, {'index': 34, '_id': 'CVx9IB_U9X4'}, {'index': 35, '_id': 'DcWqzZ3I2cY'}, {'index': 36, '_id': 'CGiDqhSdLHk'}, {'index': 37, '_id': 'VPaOy3G1-2A'}, {'index': 38, '_id': '2yHr9DPnSzk'}, {'index': 39, '_id': 'r4wLXNydzeY'}, {'index': 40, '_id': 'JN3KPFbWCy8'}, {'index': 41, '_id': 'co_MeKSnyAo'}, {'index': 42, '_id': 'MVYrJJNdrEg'}, {'index': 43, '_id': 'buarAx_u2qg'}, {'index': 44, '_id': 'fUEjCXpOjPY'}, {'index': 45, '_id': 'aGOV5R7M1Js'}, {'index': 46, '_id': 'XbPHojL_61U'}, {'index': 47, '_id': 'eTBAxD6lt2g'}, {'index': 48, '_id': 'e8qJsk1j2zE'}, {'index': 49, '_id': '34wA_bdG6QQ'}]}
# Processed transcript number 51
# Processed transcript number 52
# Processed transcript number 53
# Processed transcript number 54
# Processed transcript number 55
# Processed transcript number 56
# Processed transcript number 57
# Processed transcript number 58
# Processed transcript number 59
# Processed transcript number 60
# Processed transcript number 61
# Processed transcript number 62
# Processed transcript number 63
# Processed transcript number 64
# Processed transcript number 65
# Processed transcript number 66
# Processed transcript number 67
# Processed transcript number 68
# Processed transcript number 69
# Processed transcript number 70
# Processed transcript number 71
# Processed transcript number 72
# Processed transcript number 73
# Processed transcript number 74
# Processed transcript number 75
# Processed transcript number 76
# Processed transcript number 77
# Processed transcript number 78
# Processed transcript number 79
# Processed transcript number 80
# Processed transcript number 81
# Processed transcript number 82
# Processed transcript number 83
# Processed transcript number 84
# Processed transcript number 85
# Processed transcript number 86
# Processed transcript number 87
# Error retrieving transcript for aJoRMFWn2Jk: no element found: line 1, column 0
# Transcript for Dennis Whyte: Nuclear Fusion and the Future of Energy | Lex Fridman Podcast #353 not retrieved successfully
# Processed transcript number 88
# Processed transcript number 89
# Processed transcript number 90
# Error retrieving transcript for pNlfHgHJweQ: no element found: line 1, column 0
# Transcript for Bhaskar Sunkara: Socialism and Communism | Lex Fridman Podcast #349 not retrieved successfully
# Processed transcript number 91
# Processed transcript number 92
# Processed transcript number 93
# Processed transcript number 94
# Processed transcript number 95
# Processed transcript number 96
# Processed transcript number 97
# Processed transcript number 98
# Processed transcript number 99
# Processed transcript number 100
# Bulk upsert result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 50, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': [{'index': 0, '_id': 'Mde2q7GFCrw'}, {'index': 1, '_id': 'XpC7SVDXimg'}, {'index': 2, '_id': 'NPtBkw5uD-0'}, {'index': 3, '_id': 'dNrTrx42DGQ'}, {'index': 4, '_id': '-hxeDjAxvJ8'}, {'index': 5, '_id': 'diJp4zoQPqo'}, {'index': 6, '_id': '8qgIFD0PaWo'}, {'index': 7, '_id': 'Ff4fRgnuFgQ'}, {'index': 8, '_id': '8TmV6KEYkK0'}, {'index': 9, '_id': 'pdJQ8iVTwj8'}, {'index': 10, '_id': 'YDjOS0VHEr4'}, {'index': 11, '_id': 'iFXGpKf9VBU'}, {'index': 12, '_id': 'IQnUa5Bq5x4'}, {'index': 13, '_id': 'DgTjSrrf6GQ'}, {'index': 14, '_id': 'PdE-waSx-d8'}, {'index': 15, '_id': '2i31fDkaK9A'}, {'index': 16, '_id': 'cLVdsZ3I5os'}, {'index': 17, '_id': 'wMavKrA-4do'}, {'index': 18, '_id': 'OgIo36F6Fsg'}, {'index': 19, '_id': 'VcVfceTsD0A'}, {'index': 20, '_id': 'Osh0-J3T2nY'}, {'index': 21, '_id': 'gPfriiHBBek'}, {'index': 22, '_id': 'AaTRHFaaPG8'}, {'index': 23, '_id': 'L_Guz73e6fw'}, {'index': 24, '_id': 'qtOKrG_wK5A'}, {'index': 25, '_id': 'Qyrjgf-_Vdk'}, {'index': 26, '_id': '8EguLJgkc54'}, {'index': 27, '_id': 'hLZ6PACCBy8'}, {'index': 28, '_id': 'XiCxj-bXu5M'}, {'index': 29, '_id': 'J1lN9zkK_k0'}, {'index': 30, '_id': 'GkZz2I6sK08'}, {'index': 31, '_id': 'y3cw_9ELpQw'}, {'index': 32, '_id': 'cFSrxSBrgSc'}, {'index': 33, '_id': 'jRBksDVs4tg'}, {'index': 34, '_id': '5eK5A_43pkE'}, {'index': 35, '_id': 'uZN5xjoS6TU'}, {'index': 36, '_id': 'GvX-heRWFfA'}, {'index': 37, '_id': 'BOKCNUqbpH0'}, {'index': 38, '_id': 'Z3_PwvvfxIU'}, {'index': 39, '_id': 'NXU_M4030nE'}, {'index': 40, '_id': 'yyBosLx7bbM'}, {'index': 41, '_id': 'NUkXluf3OYA'}, {'index': 42, '_id': '9PIOoJMMptA'}, {'index': 43, '_id': 'hi9Rf0oLdHk'}, {'index': 44, '_id': '2oHH4aClJQs'}, {'index': 45, '_id': 'FhfmGM6hswI'}, {'index': 46, '_id': 'H9AAnV59ddE'}, {'index': 47, '_id': '-DVyjdw4t9I'}, {'index': 48, '_id': '4KiO8GRgwDk'}, {'index': 49, '_id': '5Gk9gIpGvSE'}]}
# Processed transcript number 101
# Processed transcript number 102
# Processed transcript number 103
# Processed transcript number 104
# Processed transcript number 105
# Processed transcript number 106
# Processed transcript number 107
# Processed transcript number 108
# Processed transcript number 109
# Processed transcript number 110
# Processed transcript number 111
# Processed transcript number 112
# Processed transcript number 113
# Processed transcript number 114
# Processed transcript number 115
# Processed transcript number 116
# Processed transcript number 117
# Processed transcript number 118
# Processed transcript number 119
# Processed transcript number 120
# Processed transcript number 121
# Processed transcript number 122
# Processed transcript number 123
# Processed transcript number 124
# Processed transcript number 125
# Processed transcript number 126
# Processed transcript number 127
# Processed transcript number 128
# Processed transcript number 129
# Processed transcript number 130
# Processed transcript number 131
# Processed transcript number 132
# Processed transcript number 133
# Processed transcript number 134
# Processed transcript number 135
# Error retrieving transcript for 1XGiTDWfdpM: no element found: line 1, column 0
# Transcript for Steve Keen: Marxism, Capitalism, and Economics | Lex Fridman Podcast #303 not retrieved successfully
# Processed transcript number 136
# Processed transcript number 137
# Processed transcript number 138
# Processed transcript number 139
# Error retrieving transcript for j4PEu4sVD40:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=j4PEu4sVD40! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Susan Cain: The Power of Introverts and Loneliness | Lex Fridman Podcast #298 not retrieved successfully
# Processed transcript number 140
# Processed transcript number 141
# Processed transcript number 142
# Processed transcript number 143
# Processed transcript number 144
# Processed transcript number 145
# Processed transcript number 146
# Processed transcript number 147
# Processed transcript number 148
# Processed transcript number 149
# Processed transcript number 150
# Bulk upsert result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 50, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': [{'index': 0, '_id': 'kFQUDCgMjRc'}, {'index': 1, '_id': 'bqeuFiAUU4o'}, {'index': 2, '_id': 'AF8DOS4C2KM'}, {'index': 3, '_id': 'vNhSCF9i8Qs'}, {'index': 4, '_id': 'OYsYgzzsdT0'}, {'index': 5, '_id': 'cdiD-9MMpb0'}, {'index': 6, '_id': '4AWLcxTGZPA'}, {'index': 7, '_id': 'VeH7qKZr0WI'}, {'index': 8, '_id': 'oJNvxYEcVAY'}, {'index': 9, '_id': 'ZFntEFXKDHM'}, {'index': 10, '_id': 'iZRbD7q1n-U'}, {'index': 11, '_id': 'iSMpTmibeDw'}, {'index': 12, '_id': 'q6zEzZCtkXw'}, {'index': 13, '_id': 'p3lsYlod5OU'}, {'index': 14, '_id': 'rKnoNfajUgM'}, {'index': 15, '_id': 'xewD1apJNhw'}, {'index': 16, '_id': '36_rM7wpN5A'}, {'index': 17, '_id': 'ykY69lSpDdo'}, {'index': 18, '_id': 'SK4kMPmgKW0'}, {'index': 19, '_id': 'srUlKNLZTas'}, {'index': 20, '_id': 'tOtdJcco3YM'}, {'index': 21, '_id': 'yImlXr5Tr8g'}, {'index': 22, '_id': '7uHGlfeCBbE'}, {'index': 23, '_id': '0ZO28NtkwwQ'}, {'index': 24, '_id': 'eF-E40pxxbI'}, {'index': 25, '_id': 'sY8aFSY2zv4'}, {'index': 26, '_id': 'jdIyNMkusLE'}, {'index': 27, '_id': 'Q6tDV3BhrcM'}, {'index': 28, '_id': 'T3FC7qIAGZk'}, {'index': 29, '_id': 'I845O57ZSy4'}, {'index': 30, '_id': 'qLDp-aYnR1Y'}, {'index': 31, '_id': 'VBPTFlpv31k'}, {'index': 32, '_id': 'aGBLRlLe7X8'}, {'index': 33, '_id': '50r-5ULcWgY'}, {'index': 34, '_id': 'WgytXF0SPh0'}, {'index': 35, '_id': 'hppbxV9C63g'}, {'index': 36, '_id': 'dSVLjAdo8UA'}, {'index': 37, '_id': 'gk4tEO4jDUM'}, {'index': 38, '_id': 'Gfr50f6ZBvo'}, {'index': 39, '_id': 'XOPO9J7DIXw'}, {'index': 40, '_id': 'EG7I6Bt_NZY'}, {'index': 41, '_id': 'o0Bi-q89j5Y'}, {'index': 42, '_id': '4oDZyOf6CW4'}, {'index': 43, '_id': 'reYdQYZ9Rj4'}, {'index': 44, '_id': 'KBZP4rLk6bk'}, {'index': 45, '_id': 'f0un-l1L8Zw'}, {'index': 46, '_id': 'jvGZkf87aCs'}, {'index': 47, '_id': '2a7CDKqWcZ0'}, {'index': 48, '_id': 'iZjby1LkTWQ'}, {'index': 49, '_id': 'tOTenjh_8hw'}]}
# Processed transcript number 151
# Processed transcript number 152
# Processed transcript number 153
# Processed transcript number 154
# Processed transcript number 155
# Processed transcript number 156
# Processed transcript number 157
# Processed transcript number 158
# Processed transcript number 159
# Processed transcript number 160
# Processed transcript number 161
# Error retrieving transcript for H_szemxPcTI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=H_szemxPcTI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Rick Rubin: Legendary Music Producer | Lex Fridman Podcast #275 not retrieved successfully
# Processed transcript number 162
# Processed transcript number 163
# Processed transcript number 164
# Processed transcript number 165
# Processed transcript number 166
# Processed transcript number 167
# Processed transcript number 168
# Processed transcript number 169
# Processed transcript number 170
# Processed transcript number 171
# Processed transcript number 172
# Processed transcript number 173
# Processed transcript number 174
# Processed transcript number 175
# Processed transcript number 176
# Processed transcript number 177
# Processed transcript number 178
# Processed transcript number 179
# Processed transcript number 180
# Processed transcript number 181
# Processed transcript number 182
# Processed transcript number 183
# Processed transcript number 184
# Processed transcript number 185
# Processed transcript number 186
# Processed transcript number 187
# Error retrieving transcript for Vrz8YDl9CeA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Vrz8YDl9CeA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Norman Naimark: Genocide, Stalin, Hitler, Mao, and Absolute Power | Lex Fridman Podcast #248 not retrieved successfully
# Processed transcript number 188
# Processed transcript number 189
# Processed transcript number 190
# Processed transcript number 191
# Processed transcript number 192
# Processed transcript number 193
# Processed transcript number 194
# Processed transcript number 195
# Processed transcript number 196
# Processed transcript number 197
# Processed transcript number 198
# Processed transcript number 199
# Processed transcript number 200
# Bulk upsert result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 50, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': [{'index': 0, '_id': 'ygAqYC8JOQI'}, {'index': 1, '_id': 'YbJZnShMQAo'}, {'index': 2, '_id': 'gp4U5aH_T6A'}, {'index': 3, '_id': '1C2tPFCGL1U'}, {'index': 4, '_id': 'sndW9hzX-wA'}, {'index': 5, '_id': 'KOwm7GUjcg8'}, {'index': 6, '_id': 'KMgPxVnKLSk'}, {'index': 7, '_id': 'SFxIazwNP_0'}, {'index': 8, '_id': 'dHTgffkpeYo'}, {'index': 9, '_id': 'lvh3g7eszVQ'}, {'index': 10, '_id': 'mC43pZkpTec'}, {'index': 11, '_id': 'OaeYUm06in0'}, {'index': 12, '_id': 'DbXjoXnIxQo'}, {'index': 13, '_id': 'cC1LFC0KFSw'}, {'index': 14, '_id': 'KW8Vjs84Fxg'}, {'index': 15, '_id': 'urdNsyZBqhQ'}, {'index': 16, '_id': 'ZecQ64l-gKM'}, {'index': 17, '_id': 'Y3VBCWIDEzk'}, {'index': 18, '_id': '5zOHSysMmH0'}, {'index': 19, '_id': 'hy2G3PhGm-g'}, {'index': 20, '_id': 'nvBEXXnNaNQ'}, {'index': 21, '_id': '0Jd7fJgFkPU'}, {'index': 22, '_id': 'arrokG3wCdE'}, {'index': 23, '_id': 'uTCc2-1tbBQ'}, {'index': 24, '_id': 'BCdV6BMMpOo'}, {'index': 25, '_id': 'KdmDtqB46Jc'}, {'index': 26, '_id': '3Z7WimACqG8'}, {'index': 27, '_id': 'SGzMElJ11Cc'}, {'index': 28, '_id': 'nhGwJLXzHs8'}, {'index': 29, '_id': 'Q24cpnHzx8I'}, {'index': 30, '_id': 'WzsivT_Ap1w'}, {'index': 31, '_id': 'oIOGUYOPAsA'}, {'index': 32, '_id': 'B2tXN7ZnSfU'}, {'index': 33, '_id': 'DxREm3s1scA'}, {'index': 34, '_id': 'TISMidxdZoc'}, {'index': 35, '_id': 'X0-SXS6zdEQ'}, {'index': 36, '_id': 'Z_LhPMhkEdw'}, {'index': 37, '_id': 'K78jqx9fx2I'}, {'index': 38, '_id': 'nDDJFvuFXdc'}, {'index': 39, '_id': 'Ww6pfsWmkdY'}, {'index': 40, '_id': 'CDiqA4SJNpA'}, {'index': 41, '_id': '3pvpNKUPbIY'}, {'index': 42, '_id': 'tApj7Q37P2k'}, {'index': 43, '_id': 'U_AREIyd0Fc'}, {'index': 44, '_id': 'xAfdSak2fs8'}, {'index': 45, '_id': 'xF6x1ftN-H4'}, {'index': 46, '_id': 'mRZE-SJShkE'}, {'index': 47, '_id': 'a3Wpy6gE4So'}, {'index': 48, '_id': 'uy1fX2vOAEE'}, {'index': 49, '_id': '80OvNaEgmmw'}]}
# Processed transcript number 201
# Processed transcript number 202
# Processed transcript number 203
# Processed transcript number 204
# Processed transcript number 205
# Processed transcript number 206
# Processed transcript number 207
# Processed transcript number 208
# Processed transcript number 209
# Processed transcript number 210
# Processed transcript number 211
# Processed transcript number 212
# Processed transcript number 213
# Processed transcript number 214
# Processed transcript number 215
# Processed transcript number 216
# Processed transcript number 217
# Processed transcript number 218
# Processed transcript number 219
# Processed transcript number 220
# Processed transcript number 221
# Processed transcript number 222
# Processed transcript number 223
# Processed transcript number 224
# Processed transcript number 225
# Processed transcript number 226
# Processed transcript number 227
# Processed transcript number 228
# Error retrieving transcript for FUS6ceIvUnI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=FUS6ceIvUnI! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (FUS6ceIvUnI) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - vi ("Vietnamese (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Ishan Misra: Self-Supervised Deep Learning in Computer Vision | Lex Fridman Podcast #206 not retrieved successfully
# Processed transcript number 229
# Processed transcript number 230
# Processed transcript number 231
# Processed transcript number 232
# Processed transcript number 233
# Processed transcript number 234
# Processed transcript number 235
# Processed transcript number 236
# Processed transcript number 237
# Processed transcript number 238
# Processed transcript number 239
# Processed transcript number 240
# Processed transcript number 241
# Error retrieving transcript for FKh8hjJNhWc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=FKh8hjJNhWc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Charles Hoskinson: Cardano | Lex Fridman Podcast #192 not retrieved successfully
# Processed transcript number 242
# Processed transcript number 243
# Processed transcript number 244
# Processed transcript number 245
# Processed transcript number 246
# Processed transcript number 247
# Processed transcript number 248
# Processed transcript number 249
# Processed transcript number 250
# Bulk upsert result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 50, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': [{'index': 0, '_id': '4-SGpEInX_c'}, {'index': 1, '_id': '3LWNY70Oj4A'}, {'index': 2, '_id': '98HZanvAJ8Y'}, {'index': 3, '_id': 'kSbMU5CbFM0'}, {'index': 4, '_id': 'PbN3HzKkW4M'}, {'index': 5, '_id': 'YJF01_ztxwY'}, {'index': 6, '_id': 'Iau6W5pjy9Y'}, {'index': 7, '_id': 'cC1HszE5Hcw'}, {'index': 8, '_id': 'KZnGSVwIpeU'}, {'index': 9, '_id': 'EwueqdgIvq4'}, {'index': 10, '_id': 'gFEE3w7F0ww'}, {'index': 11, '_id': 'uiNpESmPioQ'}, {'index': 12, '_id': 'Ui38ZzTymDY'}, {'index': 13, '_id': '3wMKoSRbGVs'}, {'index': 14, '_id': 'hZenJc1fa70'}, {'index': 15, '_id': 'EE1R8FYUJm0'}, {'index': 16, '_id': 'Fx0G6DHMfXM'}, {'index': 17, '_id': 'nre0QT9LN6w'}, {'index': 18, '_id': 'G433fa01oMU'}, {'index': 19, '_id': 'U5OD8MjYnOM'}, {'index': 20, '_id': 'TRdL6ZzWBS0'}, {'index': 21, '_id': 'J48bm21q8_A'}, {'index': 22, '_id': 'rIpUf-Vy2JA'}, {'index': 23, '_id': 'oYQh1ZNkC70'}, {'index': 24, '_id': 'Hc4XvHTlW3s'}, {'index': 25, '_id': 'ndMahzDCH1Y'}, {'index': 26, '_id': 'Z1KwkpTUbkg'}, {'index': 27, '_id': 'e4Bet29PVPY'}, {'index': 28, '_id': '0RTWSJAqTPg'}, {'index': 29, '_id': 'j4_VyRDOmN4'}, {'index': 30, '_id': 'ew8U43IXTfk'}, {'index': 31, '_id': '2tUiLxtrLxk'}, {'index': 32, '_id': 'tm7poMupE8k'}, {'index': 33, '_id': 'R5rNoV1Qy_Q'}, {'index': 34, '_id': 'Udh22kuLebg'}, {'index': 35, '_id': '-tDQ74I3Ovs'}, {'index': 36, '_id': 'n2RcVEftY48'}, {'index': 37, '_id': 'usDqSEKDVsA'}, {'index': 38, '_id': 'CGAvsmokB4c'}, {'index': 39, '_id': 'TG6BuSjwP4o'}, {'index': 40, '_id': 'cuD9uNFXnU8'}, {'index': 41, '_id': 'hGRNUw559SE'}, {'index': 42, '_id': 'tueAcSiiqYA'}, {'index': 43, '_id': 'jhKZIq3SlYE'}, {'index': 44, '_id': 'XW0QZmtbjvs'}, {'index': 45, '_id': 'LDTe8uFqbws'}, {'index': 46, '_id': '1YbcB6b4A2U'}, {'index': 47, '_id': '4dC_nRYIDZU'}, {'index': 48, '_id': '85F0FDsPHf8'}, {'index': 49, '_id': '6z1JwZbX4dQ'}]}
# Processed transcript number 251
# Processed transcript number 252
# Processed transcript number 253
# Processed transcript number 254
# Error retrieving transcript for Pl3x4GINtBQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Pl3x4GINtBQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Michael Malice and Yaron Brook: Ayn Rand, Human Nature, and Anarchy | Lex Fridman Podcast #178 not retrieved successfully
# Processed transcript number 255
# Error retrieving transcript for HrehEWYj16s:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=HrehEWYj16s! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Robert Breedlove: Philosophy of Bitcoin from First Principles | Lex Fridman Podcast #176 not retrieved successfully
# Processed transcript number 256
# Processed transcript number 257
# Processed transcript number 258
# Processed transcript number 259
# Processed transcript number 260
# Processed transcript number 261
# Processed transcript number 262
# Processed transcript number 263
# Processed transcript number 264
# Processed transcript number 265
# Processed transcript number 266
# Processed transcript number 267
# Processed transcript number 268
# Processed transcript number 269
# Processed transcript number 270
# Processed transcript number 271
# Processed transcript number 272
# Processed transcript number 273
# Processed transcript number 274
# Processed transcript number 275
# Error retrieving transcript for plcc6E-E1uU: no element found: line 1, column 0
# Transcript for Avi Loeb: Aliens, Black Holes, and the Mystery of the Oumuamua | Lex Fridman Podcast #154 not retrieved successfully
# Processed transcript number 276
# Processed transcript number 277
# Processed transcript number 278
# Processed transcript number 279
# Processed transcript number 280
# Processed transcript number 281
# Processed transcript number 282
# Processed transcript number 283
# Processed transcript number 284
# Processed transcript number 285
# Processed transcript number 286
# Processed transcript number 287
# Error retrieving transcript for NOReE-3EBhI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=NOReE-3EBhI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Erik Brynjolfsson: Economics of AI, Social Networks, and Technology | Lex Fridman Podcast #141 not retrieved successfully
# Processed transcript number 288
# Processed transcript number 289
# Processed transcript number 290
# Processed transcript number 291
# Processed transcript number 292
# Error retrieving transcript for LAyZ8IYfGxQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=LAyZ8IYfGxQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Charles Isbell: Computing, Interactive AI, and Race in America | Lex Fridman Podcast #135 not retrieved successfully
# Processed transcript number 293
# Processed transcript number 294
# Processed transcript number 295
# Error retrieving transcript for nWTvXbQHwWs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=nWTvXbQHwWs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Chris Lattner: The Future of Computing and Programming Languages | Lex Fridman Podcast #131 not retrieved successfully
# Processed transcript number 296
# Processed transcript number 297
# Processed transcript number 298
# Processed transcript number 299
# Processed transcript number 300
# Bulk upsert result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 50, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': [{'index': 0, '_id': 'ktuw6Ow4sd0'}, {'index': 1, '_id': 'TPXTmVdlyoc'}, {'index': 2, '_id': 'USnqkUAr_3w'}, {'index': 3, '_id': 'fIPxfzfOTxk'}, {'index': 4, '_id': 'CY_LEa9xQtg'}, {'index': 5, '_id': 'dmVqpx4YOY4'}, {'index': 6, '_id': '7Grseeycor4'}, {'index': 7, '_id': 'mDyBbGCiBUU'}, {'index': 8, '_id': 'UOEpe17nPhE'}, {'index': 9, '_id': 'IHg6ixt3CKc'}, {'index': 10, '_id': 'Iuven0crywo'}, {'index': 11, '_id': 'VHg9sfOzBbY'}, {'index': 12, '_id': 'zNdhgOk4-fE'}, {'index': 13, '_id': 'grceJbuPUXI'}, {'index': 14, '_id': 'y3Umo_jd5AA'}, {'index': 15, '_id': 'ClxRHJPz8aQ'}, {'index': 16, '_id': 'ifX_JnBfxTY'}, {'index': 17, '_id': 'G4hL5Om4IJ4'}, {'index': 18, '_id': 'd2bYwYxqJCM'}, {'index': 19, '_id': 'krB0enBeSiE'}, {'index': 20, '_id': 'ziQSpuST6Es'}, {'index': 21, '_id': 'QSPtSNqUCUw'}, {'index': 22, '_id': 'CejJ2aVRUE8'}, {'index': 23, '_id': '8wYZjOzfTUk'}, {'index': 24, '_id': 'RL4j4KPwNGM'}, {'index': 25, '_id': 'I51DuprOb0o'}, {'index': 26, '_id': 'pRzelZlKl7E'}, {'index': 27, '_id': 'yTWa-Z1UQwU'}, {'index': 28, '_id': 'uykM3NhJbso'}, {'index': 29, '_id': 'iqBh7G4uDR8'}, {'index': 30, '_id': 'yzMVEbs8Zz0'}, {'index': 31, '_id': 'P6prRXkI5HM'}, {'index': 32, '_id': 'L-RuvUkcyJI'}, {'index': 33, '_id': 'ICj8p5jPd3Y'}, {'index': 34, '_id': 'c9AbECvRt20'}, {'index': 35, '_id': 'RvhpncC5jZ8'}, {'index': 36, '_id': 'bgNzUxyS-kQ'}, {'index': 37, '_id': 'S_AFc_BXht4'}, {'index': 38, '_id': 'Ktj050DxG7Q'}, {'index': 39, '_id': 'SOr1YYRljV8'}, {'index': 40, '_id': 'WxfA1OSev4c'}, {'index': 41, '_id': '-k-ztNsBM54'}, {'index': 42, '_id': 'o2nG7-eXxko'}, {'index': 43, '_id': 'Aq9UPIXbtKI'}, {'index': 44, '_id': '_L3gNaAVjQ4'}, {'index': 45, '_id': 'nAMjv0NAESM'}, {'index': 46, '_id': 'NbdRIVCBqNI'}, {'index': 47, '_id': 'BIk1zUy8ehU'}, {'index': 48, '_id': 'FKCJWkPehdY'}, {'index': 49, '_id': 'IT__Nrr3PNI'}]}
# Processed transcript number 301
# Processed transcript number 302
# Processed transcript number 303
# Processed transcript number 304
# Processed transcript number 305
# Processed transcript number 306
# Processed transcript number 307
# Processed transcript number 308
# Processed transcript number 309
# Processed transcript number 310
# Processed transcript number 311
# Processed transcript number 312
# Processed transcript number 313
# Processed transcript number 314
# Processed transcript number 315
# Processed transcript number 316
# Processed transcript number 317
# Processed transcript number 318
# Processed transcript number 319
# Processed transcript number 320
# Processed transcript number 321
# Processed transcript number 322
# Processed transcript number 323
# Processed transcript number 324
# Processed transcript number 325
# Processed transcript number 326
# Processed transcript number 327
# Processed transcript number 328
# Processed transcript number 329
# Processed transcript number 330
# Processed transcript number 331
# Processed transcript number 332
# Processed transcript number 333
# Processed transcript number 334
# Processed transcript number 335
# Processed transcript number 336
# Processed transcript number 337
# Processed transcript number 338
# Processed transcript number 339
# Processed transcript number 340
# Processed transcript number 341
# Processed transcript number 342
# Processed transcript number 343
# Processed transcript number 344
# Processed transcript number 345
# Processed transcript number 346
# Processed transcript number 347
# Processed transcript number 348
# Processed transcript number 349
# Processed transcript number 350
# Bulk upsert result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 50, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': [{'index': 0, '_id': 'hhEwWghH_XM'}, {'index': 1, '_id': '-t1_ffaFXao'}, {'index': 2, '_id': 't06rkOOUa7g'}, {'index': 3, '_id': 'aB8zcAttP1E'}, {'index': 4, '_id': '_AGPbvCDBCk'}, {'index': 5, '_id': 'PUAdj3w3wO4'}, {'index': 6, '_id': '386s-y1aRRo'}, {'index': 7, '_id': 'U_6AYX42gkU'}, {'index': 8, '_id': 'qfKyNxfyWbo'}, {'index': 9, '_id': '-jA2ABHBc6Y'}, {'index': 10, '_id': 'tg_m_LxxRwM'}, {'index': 11, '_id': 'A22Ej6kb2wo'}, {'index': 12, '_id': 'brslF-Cy3HU'}, {'index': 13, '_id': 'pDSEjaDCtOU'}, {'index': 14, '_id': 'KllCrlfLuzs'}, {'index': 15, '_id': 'LRYkH-fAVGE'}, {'index': 16, '_id': 'O9upVbGSBFo'}, {'index': 17, '_id': 'kxi-_TT_-Nc'}, {'index': 18, '_id': 'llh-2pqSGrs'}, {'index': 19, '_id': '3t06ajvBtl0'}, {'index': 20, '_id': '9LQffCdHHlQ'}, {'index': 21, '_id': 'naed4C4hfAg'}, {'index': 22, '_id': 'OpSmCKe27WE'}, {'index': 23, '_id': 'PgtedwKGhXs'}, {'index': 24, '_id': 'P-2P3MSZrBM'}, {'index': 25, '_id': 'NwzuibY5kUs'}, {'index': 26, '_id': '7KTbEn7PiaY'}, {'index': 27, '_id': 'M1-v-dXIzho'}, {'index': 28, '_id': 'aYwDs9LTN50'}, {'index': 29, '_id': 'HhY95m-WD_E'}, {'index': 30, '_id': '13CZPWmke6A'}, {'index': 31, '_id': 'xlMTWfkQqbY'}, {'index': 32, '_id': '8A-5gIW0-eI'}, {'index': 33, '_id': '60KJz1BVTyU'}, {'index': 34, '_id': 'CwyOUS8TSl0'}, {'index': 35, '_id': 'ez773teNFYA'}, {'index': 36, '_id': 'rIAZJNe7YtE'}, {'index': 37, '_id': '5f-JlzBuUUU'}, {'index': 38, '_id': 'uPUEq8d73JI'}, {'index': 39, '_id': 'orMtwOz6Db0'}, {'index': 40, '_id': 'rfKiTGj-zeQ'}, {'index': 41, '_id': '_TTNGq9djU4'}, {'index': 42, '_id': 'iOCfIFBBpVY'}, {'index': 43, '_id': '3x1b_S6Qp2Q'}, {'index': 44, '_id': 'WgLo4gmEraU'}, {'index': 45, '_id': '7jFdxd1qX2g'}, {'index': 46, '_id': 'gU-mkuMU428'}, {'index': 47, '_id': 'DKyzcbNr8WE'}, {'index': 48, '_id': 'E1AxVXt2Gv4'}, {'index': 49, '_id': 'EYIKy_FM9x0'}]}
# Processed transcript number 351
# Processed transcript number 352
# Processed transcript number 353
# Processed transcript number 354
# Processed transcript number 355
# Processed transcript number 356
# Processed transcript number 357
# Processed transcript number 358
# Processed transcript number 359
# Processed transcript number 360
# Processed transcript number 361
# Processed transcript number 362
# Processed transcript number 363
# Processed transcript number 364
# Processed transcript number 365
# Processed transcript number 366
# Processed transcript number 367
# Processed transcript number 368
# Processed transcript number 369
# Processed transcript number 370
# Processed transcript number 371
# Processed transcript number 372
# Processed transcript number 373
# Processed transcript number 374
# Processed transcript number 375
# Processed transcript number 376
# Processed transcript number 377
# Processed transcript number 378
# Processed transcript number 379
# Processed transcript number 380
# Error retrieving transcript for vNOTDn3D_RI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=vNOTDn3D_RI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Gary Marcus: Toward a Hybrid of Deep Learning and Symbolic AI | Lex Fridman Podcast #43 not retrieved successfully
# Processed transcript number 381
# Processed transcript number 382
# Processed transcript number 383
# Processed transcript number 384
# Processed transcript number 385
# Processed transcript number 386
# Processed transcript number 387
# Processed transcript number 388
# Processed transcript number 389
# Processed transcript number 390
# Processed transcript number 391
# Processed transcript number 392
# Processed transcript number 393
# Processed transcript number 394
# Processed transcript number 395
# Processed transcript number 396
# Processed transcript number 397
# Processed transcript number 398
# Processed transcript number 399
# Error retrieving transcript for q0mokx-iiws:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=q0mokx-iiws! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript for Gavin Miller: Adobe Research | Lex Fridman Podcast #23 not retrieved successfully
# Processed transcript number 400
# Bulk upsert result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 50, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': [{'index': 0, '_id': '0jspaMLxBig'}, {'index': 1, '_id': 'uX5t8EivCaM'}, {'index': 2, '_id': 'bQa7hpUpMzM'}, {'index': 3, '_id': 'Nb2tebYAaOA'}, {'index': 4, '_id': 'LW59lMvxmY4'}, {'index': 5, '_id': 'nkWmiNRPU-c'}, {'index': 6, '_id': 'OJQepiqSWvg'}, {'index': 7, '_id': 'J21-7AsUcgM'}, {'index': 8, '_id': 'UwwBG-MbniY'}, {'index': 9, '_id': 'U_lKUK2MCsg'}, {'index': 10, '_id': 'oCkkjnpS2f8'}, {'index': 11, '_id': '2BdBfsXbST8'}, {'index': 12, '_id': 'ImKkaeUx1MU'}, {'index': 13, '_id': 'IUHkhB366tE'}, {'index': 14, '_id': 'ZPPAOakITeQ'}, {'index': 15, '_id': '3qMemn__kK8'}, {'index': 16, '_id': 'Ad89JYS-uZM'}, {'index': 17, '_id': 'pEBI0vF45ic'}, {'index': 18, '_id': '0-3kw5BEKB8'}, {'index': 19, '_id': 'M95m2EFb7IQ'}, {'index': 20, '_id': 'cMscNuSUy0I'}, {'index': 21, '_id': 'lEZPfmGCEk0'}, {'index': 22, '_id': '2fI6bYnRgSc'}, {'index': 23, '_id': 'AzdxbzHtjgs'}, {'index': 24, '_id': 'smK9dgdTl40'}, {'index': 25, '_id': 'uTxRF5ag27A'}, {'index': 26, '_id': 'iNqqOLscOBY'}, {'index': 27, '_id': '8RVa0THWUWw'}, {'index': 28, '_id': 'kD5yc1LQrpQ'}, {'index': 29, '_id': 'Whtt2H5_isM'}, {'index': 30, '_id': '_VPxEcT_Adc'}, {'index': 31, '_id': 's78hvV3QLUE'}, {'index': 32, '_id': 'x0-zGdlpTeg'}, {'index': 33, '_id': '1d9Dj9dT_pw'}, {'index': 34, '_id': 'Bo8MY4JpiXE'}, {'index': 35, '_id': 'HYsLTNXMl1Q'}, {'index': 36, '_id': 'SGSOCuByo24'}, {'index': 37, '_id': 'J6XcP4JOHmk'}, {'index': 38, '_id': 'i6rnzk8VU24'}, {'index': 39, '_id': 'anXep8kBOCg'}, {'index': 40, '_id': 'lVHRs3uTHNI'}, {'index': 41, '_id': 'iwcYp-XT7UI'}, {'index': 42, '_id': 'QDN6xvhAw94'}, {'index': 43, '_id': 'v-9Mpe7NhkM'}, {'index': 44, '_id': 'Tj6NOfdfa4o'}, {'index': 45, '_id': 'cQ48rP_Rs4g'}, {'index': 46, '_id': 'l-NJrvyRo0c'}, {'index': 47, '_id': '-EVqrDlAqYo'}, {'index': 48, '_id': 'kq0VO1FqE6I'}, {'index': 49, '_id': 'NERNE4UThHU'}]}
# Processed transcript number 401
# Processed transcript number 402
# Processed transcript number 403
# Processed transcript number 404
# Processed transcript number 405
# Processed transcript number 406
# Processed transcript number 407
# Processed transcript number 408
# Processed transcript number 409
# Processed transcript number 410
# Processed transcript number 411
# Processed transcript number 412
# Processed transcript number 413
# Processed transcript number 414
# Processed transcript number 415
# Processed transcript number 416
# Processed transcript number 417
# Processed transcript number 418
# Processed transcript number 419
# Bulk upsert result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 19, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': [{'index': 0, '_id': 'yCd3CzGSte8'}, {'index': 1, '_id': 'Kedt2or9xlo'}, {'index': 2, '_id': 'Z6rxFNMGdn0'}, {'index': 3, '_id': 'dEv99vxKjVI'}, {'index': 4, '_id': 'bIrEM2FbOLU'}, {'index': 5, '_id': '2wq9x2QcZN0'}, {'index': 6, '_id': 'Er7Dy8rvqOc'}, {'index': 7, '_id': 'YUYagvESisE'}, {'index': 8, '_id': 'aSyZvBrPAyk'}, {'index': 9, '_id': 'b7bStIQovcY'}, {'index': 10, '_id': '3FIo6evmweo'}, {'index': 11, '_id': 'l-mYLq6eZPY'}, {'index': 12, '_id': 'KsZI5oXBC0k'}, {'index': 13, '_id': 'hIC9FQpxVwQ'}, {'index': 14, '_id': 'KZkYSSE8HHI'}, {'index': 15, '_id': 'ghwaIiE3Nd8'}, {'index': 16, '_id': 'STFcvzoxVw4'}, {'index': 17, '_id': 'azOmzumh0vQ'}, {'index': 18, '_id': 'epQxfSp-rdU'}]}

# %%
print(f"Number of missing transcripts: {len(missing_transcripts)}")
print(f"Missing transcripts: {missing_transcripts}")
# Out:
# Number of missing transcripts: 16
# Missing transcripts: ['aJoRMFWn2Jk', 'pNlfHgHJweQ', '1XGiTDWfdpM', 'j4PEu4sVD40', 'H_szemxPcTI', 'Vrz8YDl9CeA', 'FUS6ceIvUnI', 'FKh8hjJNhWc', 'Pl3x4GINtBQ', 'HrehEWYj16s', 'plcc6E-E1uU', 'NOReE-3EBhI', 'LAyZ8IYfGxQ', 'nWTvXbQHwWs', 'vNOTDn3D_RI', 'q0mokx-iiws']

# %%
all_transcripts = mu.get_documents(collection)
print(f"Number of transcripts in the collection: {len(all_transcripts)}")
# Out:
# Number of transcripts in the collection: 420
